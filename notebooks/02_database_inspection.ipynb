# %% [markdown]
# # dbt Build & Database Inspection
#
# This notebook provides:
# 1. **dbt commands** - Run and test your dbt models
# 2. **SQL linting** - Check SQL format quality with sqlfluff
# 3. **Database inspection** - Explore schemas, tables, views, and SQL definitions

# %% [markdown]
# ## Part 1: dbt Commands
#
# Run dbt commands to build and test your models before inspecting the database.

# %%
import subprocess
import os
from pathlib import Path

# Set project paths
project_root = Path('..').resolve()
dbt_project_dir = project_root / 'dbt' / 'ecommerce_analytics'
dbt_profiles_dir = project_root / 'dbt'

print(f"Project root: {project_root}")
print(f"dbt project: {dbt_project_dir}")
print(f"dbt profiles: {dbt_profiles_dir}")
# Out:
# Project root: D:\repos\dbt-ml-analytics-pipeline
# dbt project: D:\repos\dbt-ml-analytics-pipeline\dbt\ecommerce_analytics
# dbt profiles: D:\repos\dbt-ml-analytics-pipeline\dbt

# %%
def run_dbt_command(command, *args):
    """
    Run a dbt command and display the output.
    
    Args:
        command: dbt command (e.g., 'run', 'test', 'build')
        *args: Additional arguments (e.g., '--select', 'stg_orders')
    
    Examples:
        run_dbt_command('run')
        run_dbt_command('run', '--select', 'staging')
        run_dbt_command('test', '--select', 'fct_orders')
    """
    # Build the command
    cmd = [
        'dbt', command,
        '--profiles-dir', str(dbt_profiles_dir),
        '--project-dir', str(dbt_project_dir)
    ]
    cmd.extend(args)
    
    print(f"Running: {' '.join(cmd)}")
    print("=" * 80)
    
    # Run the command
    result = subprocess.run(
        cmd,
        cwd=project_root,
        capture_output=True,
        text=True
    )
    
    # Display output
    print(result.stdout)
    if result.stderr:
        print("STDERR:", result.stderr)
    
    print("=" * 80)
    print(f"Return code: {result.returncode}")
    
    return result

print("dbt command helper loaded successfully!")
# Out:
# dbt command helper loaded successfully!

# %% [markdown]
# ### Common dbt Commands
#
# Run these cells to execute dbt commands. Uncomment the ones you want to run.

# %%
# Run all models
# run_dbt_command('run')

# %%
# Run only staging models
# run_dbt_command('run', '--select', 'staging')

# %%
# Run a specific model and its downstream dependencies
# run_dbt_command('run', '--select', 'stg_orders+')

# %%
# Run all tests
# run_dbt_command('test')

# %%
# Test a specific model
# run_dbt_command('test', '--select', 'fct_orders')

# %%
# Run and test all models (build command)
run_dbt_command('build')
# Out:
# Running: dbt build --profiles-dir D:\repos\dbt-ml-analytics-pipeline\dbt --project-dir D:\repos\dbt-ml-analytics-pipeline\dbt\ecommerce_analytics
# ================================================================================
# 17:59:58  Running with dbt=1.8.9
# 17:59:58  Registered adapter: duckdb=1.10.0
# 17:59:59  [WARNING]: Configuration paths exist in your dbt_project.yml file which do not apply to any resources.
# There are 2 unused configuration paths:
# - seeds.ecommerce_analytics
# - snapshots.ecommerce_analytics
# 17:59:59  Found 17 models, 70 data tests, 9 sources, 444 macros
# 17:59:59
# 17:59:59  Concurrency: 4 threads (target='dev')
# 17:59:59
# 17:59:59  1 of 87 START sql view model staging.stg_geolocation ........................... [RUN]
# 17:59:59  2 of 87 START sql view model staging.stg_order_payments ........................ [RUN]
# 17:59:59  3 of 87 START sql view model staging.stg_order_reviews ......................... [RUN]
# 17:59:59  4 of 87 START test source_accepted_values_raw_olist_orders_dataset_order_status__delivered__shipped__canceled__unavailable__invoiced__processing__created__approved  [RUN]
# 17:59:59  4 of 87 PASS source_accepted_values_raw_olist_orders_dataset_order_status__delivered__shipped__canceled__unavailable__invoiced__processing__created__approved  [PASS in 0.14s]
# 17:59:59  5 of 87 START test source_not_null_raw_olist_customers_dataset_customer_id ..... [RUN]
# 17:59:59  1 of 87 OK created sql view model staging.stg_geolocation ...................... [OK in 0.16s]
# 17:59:59  2 of 87 OK created sql view model staging.stg_order_payments ................... [OK in 0.16s]
# 17:59:59  6 of 87 START test source_not_null_raw_olist_customers_dataset_customer_state .. [RUN]
# 17:59:59  3 of 87 OK created sql view model staging.stg_order_reviews .................... [OK in 0.16s]
# 17:59:59  7 of 87 START test source_not_null_raw_olist_customers_dataset_customer_unique_id  [RUN]
# 17:59:59  8 of 87 START test source_not_null_raw_olist_customers_dataset_customer_zip_code_prefix  [RUN]
# 17:59:59  5 of 87 PASS source_not_null_raw_olist_customers_dataset_customer_id ........... [PASS in 0.05s]
# 17:59:59  9 of 87 START test source_not_null_raw_olist_order_items_dataset_order_id ...... [RUN]
# 17:59:59  6 of 87 PASS source_not_null_raw_olist_customers_dataset_customer_state ........ [PASS in 0.06s]
# 17:59:59  10 of 87 START test source_not_null_raw_olist_order_items_dataset_order_item_id  [RUN]
# 17:59:59  7 of 87 PASS source_not_null_raw_olist_customers_dataset_customer_unique_id .... [PASS in 0.07s]
# 17:59:59  11 of 87 START test source_not_null_raw_olist_order_items_dataset_product_id ... [RUN]
# 17:59:59  8 of 87 PASS source_not_null_raw_olist_customers_dataset_customer_zip_code_prefix  [PASS in 0.07s]
# 17:59:59  12 of 87 START test source_not_null_raw_olist_order_items_dataset_seller_id .... [RUN]
# 17:59:59  9 of 87 PASS source_not_null_raw_olist_order_items_dataset_order_id ............ [PASS in 0.07s]
# 17:59:59  13 of 87 START test source_not_null_raw_olist_orders_dataset_customer_id ....... [RUN]
# 17:59:59  10 of 87 PASS source_not_null_raw_olist_order_items_dataset_order_item_id ...... [PASS in 0.07s]
# 17:59:59  14 of 87 START test source_not_null_raw_olist_orders_dataset_order_id .......... [RUN]
# 17:59:59  12 of 87 PASS source_not_null_raw_olist_order_items_dataset_seller_id .......... [PASS in 0.06s]
# 17:59:59  15 of 87 START test source_not_null_raw_olist_orders_dataset_order_purchase_timestamp  [RUN]
# 18:00:00  11 of 87 PASS source_not_null_raw_olist_order_items_dataset_product_id ......... [PASS in 0.09s]
# 18:00:00  16 of 87 START test source_not_null_raw_olist_orders_dataset_order_status ...... [RUN]
# 18:00:00  13 of 87 PASS source_not_null_raw_olist_orders_dataset_customer_id ............. [PASS in 0.07s]
# 18:00:00  17 of 87 START test source_not_null_raw_olist_products_dataset_product_id ...... [RUN]
# 18:00:00  14 of 87 PASS source_not_null_raw_olist_orders_dataset_order_id ................ [PASS in 0.06s]
# 18:00:00  18 of 87 START test source_not_null_raw_olist_sellers_dataset_seller_id ........ [RUN]
# 18:00:00  16 of 87 PASS source_not_null_raw_olist_orders_dataset_order_status ............ [PASS in 0.04s]
# 18:00:00  19 of 87 START test source_relationships_raw_olist_order_items_dataset_order_id__order_id__source_raw_olist_orders_dataset_  [RUN]
# 18:00:00  15 of 87 PASS source_not_null_raw_olist_orders_dataset_order_purchase_timestamp  [PASS in 0.08s]
# 18:00:00  20 of 87 START test source_relationships_raw_olist_orders_dataset_customer_id__customer_id__source_raw_olist_customers_dataset_  [RUN]
# 18:00:00  17 of 87 PASS source_not_null_raw_olist_products_dataset_product_id ............ [PASS in 0.06s]
# 18:00:00  21 of 87 START test source_unique_raw_olist_customers_dataset_customer_id ...... [RUN]
# 18:00:00  18 of 87 PASS source_not_null_raw_olist_sellers_dataset_seller_id .............. [PASS in 0.06s]
# 18:00:00  22 of 87 START test source_unique_raw_olist_orders_dataset_order_id ............ [RUN]
# 18:00:00  19 of 87 PASS source_relationships_raw_olist_order_items_dataset_order_id__order_id__source_raw_olist_orders_dataset_  [PASS in 0.08s]
# 18:00:00  23 of 87 START test source_unique_raw_olist_products_dataset_product_id ........ [RUN]
# 18:00:00  20 of 87 PASS source_relationships_raw_olist_orders_dataset_customer_id__customer_id__source_raw_olist_customers_dataset_  [PASS in 0.07s]
# 18:00:00  24 of 87 START test source_unique_raw_olist_sellers_dataset_seller_id .......... [RUN]
# 18:00:00  21 of 87 PASS source_unique_raw_olist_customers_dataset_customer_id ............ [PASS in 0.06s]
# 18:00:00  25 of 87 START sql view model staging.stg_order_items .......................... [RUN]
# 18:00:00  22 of 87 PASS source_unique_raw_olist_orders_dataset_order_id .................. [PASS in 0.07s]
# 18:00:00  26 of 87 START sql view model staging.stg_customers ............................ [RUN]
# 18:00:00  24 of 87 PASS source_unique_raw_olist_sellers_dataset_seller_id ................ [PASS in 0.06s]
# 18:00:00  25 of 87 OK created sql view model staging.stg_order_items ..................... [OK in 0.05s]
# 18:00:00  23 of 87 PASS source_unique_raw_olist_products_dataset_product_id .............. [PASS in 0.07s]
# 18:00:00  27 of 87 START sql view model staging.stg_orders ............................... [RUN]
# 18:00:00  28 of 87 START sql view model staging.stg_sellers .............................. [RUN]
# 18:00:00  29 of 87 START sql view model staging.stg_products ............................. [RUN]
# 18:00:00  26 of 87 OK created sql view model staging.stg_customers ....................... [OK in 0.05s]
# 18:00:00  29 of 87 OK created sql view model staging.stg_products ........................ [OK in 0.07s]
# 18:00:00  27 of 87 OK created sql view model staging.stg_orders .......................... [OK in 0.07s]
# 18:00:00  28 of 87 OK created sql view model staging.stg_sellers ......................... [OK in 0.07s]
# 18:00:00  30 of 87 START sql view model marts.fct_order_items ............................ [RUN]
# 18:00:00  31 of 87 START sql view model marts.fct_orders ................................. [RUN]
# 18:00:00  32 of 87 START sql view model intermediate.int_customer_orders ................. [RUN]
# 18:00:00  33 of 87 START sql view model intermediate.int_product_performance ............. [RUN]
# 18:00:00  30 of 87 OK created sql view model marts.fct_order_items ....................... [OK in 0.07s]
# 18:00:00  34 of 87 START sql view model intermediate.int_seller_performance .............. [RUN]
# 18:00:00  31 of 87 OK created sql view model marts.fct_orders ............................ [OK in 0.08s]
# 18:00:00  33 of 87 OK created sql view model intermediate.int_product_performance ........ [OK in 0.08s]
# 18:00:00  35 of 87 START test not_null_fct_order_items_customer_key ...................... [RUN]
# 18:00:00  36 of 87 START test not_null_fct_order_items_order_item_key .................... [RUN]
# 18:00:00  32 of 87 OK created sql view model intermediate.int_customer_orders ............ [OK in 0.09s]
# 18:00:00  37 of 87 START test not_null_fct_order_items_order_key ......................... [RUN]
# 18:00:00  34 of 87 OK created sql view model intermediate.int_seller_performance ......... [OK in 0.05s]
# 18:00:00  38 of 87 START test not_null_fct_order_items_product_key ....................... [RUN]
# 18:00:00  37 of 87 PASS not_null_fct_order_items_order_key ............................... [PASS in 0.06s]
# 18:00:00  39 of 87 START test not_null_fct_order_items_seller_key ........................ [RUN]
# 18:00:00  36 of 87 PASS not_null_fct_order_items_order_item_key .......................... [PASS in 0.08s]
# 18:00:00  40 of 87 START test not_null_fct_order_items_total_price ....................... [RUN]
# 18:00:00  38 of 87 PASS not_null_fct_order_items_product_key ............................. [PASS in 0.08s]
# 18:00:00  41 of 87 START test unique_fct_order_items_order_item_key ...................... [RUN]
# 18:00:00  35 of 87 PASS not_null_fct_order_items_customer_key ............................ [PASS in 0.13s]
# 18:00:00  42 of 87 START test accepted_values_fct_orders_order_status__delivered__shipped__canceled__unavailable__invoiced__processing__created__approved  [RUN]
# 18:00:00  39 of 87 PASS not_null_fct_order_items_seller_key .............................. [PASS in 0.07s]
# 18:00:00  43 of 87 START test not_null_fct_orders_customer_key ........................... [RUN]
# 18:00:00  40 of 87 PASS not_null_fct_order_items_total_price ............................. [PASS in 0.07s]
# 18:00:00  44 of 87 START test not_null_fct_orders_order_key .............................. [RUN]
# 18:00:00  42 of 87 PASS accepted_values_fct_orders_order_status__delivered__shipped__canceled__unavailable__invoiced__processing__created__approved  [PASS in 0.07s]
# 18:00:00  45 of 87 START test not_null_fct_orders_order_status ........................... [RUN]
# 18:00:00  41 of 87 PASS unique_fct_order_items_order_item_key ............................ [PASS in 0.16s]
# 18:00:00  46 of 87 START test not_null_fct_orders_order_value ............................ [RUN]
# 18:00:00  43 of 87 PASS not_null_fct_orders_customer_key ................................. [PASS in 0.24s]
# 18:00:00  47 of 87 START test not_null_fct_orders_purchased_at ........................... [RUN]
# 18:00:00  44 of 87 PASS not_null_fct_orders_order_key .................................... [PASS in 0.23s]
# 18:00:00  48 of 87 START test relationships_fct_order_items_order_key__order_key__ref_fct_orders_  [RUN]
# 18:00:00  45 of 87 PASS not_null_fct_orders_order_status ................................. [PASS in 0.24s]
# 18:00:00  49 of 87 START test unique_fct_orders_order_key ................................ [RUN]
# 18:00:00  46 of 87 PASS not_null_fct_orders_order_value .................................. [PASS in 0.30s]
# 18:00:00  50 of 87 START test not_null_int_product_performance_category_english .......... [RUN]
# 18:00:01  47 of 87 PASS not_null_fct_orders_purchased_at ................................. [PASS in 0.23s]
# 18:00:01  51 of 87 START test not_null_int_product_performance_product_id ................ [RUN]
# 18:00:01  49 of 87 PASS unique_fct_orders_order_key ...................................... [PASS in 0.23s]
# 18:00:01  52 of 87 START test unique_int_product_performance_product_id .................. [RUN]
# 18:00:01  48 of 87 PASS relationships_fct_order_items_order_key__order_key__ref_fct_orders_  [PASS in 0.30s]
# 18:00:01  53 of 87 START test not_null_int_customer_orders_customer_unique_id ............ [RUN]
# 18:00:01  50 of 87 PASS not_null_int_product_performance_category_english ................ [PASS in 0.16s]
# 18:00:01  54 of 87 START test not_null_int_customer_orders_total_orders .................. [RUN]
# 18:00:01  51 of 87 PASS not_null_int_product_performance_product_id ...................... [PASS in 0.14s]
# 18:00:01  55 of 87 START test not_null_int_customer_orders_total_revenue ................. [RUN]
# 18:00:01  52 of 87 PASS unique_int_product_performance_product_id ........................ [PASS in 0.10s]
# 18:00:01  56 of 87 START test unique_int_customer_orders_customer_unique_id .............. [RUN]
# 18:00:01  53 of 87 PASS not_null_int_customer_orders_customer_unique_id .................. [PASS in 0.09s]
# 18:00:01  57 of 87 START test not_null_int_seller_performance_seller_id .................. [RUN]
# 18:00:01  56 of 87 PASS unique_int_customer_orders_customer_unique_id .................... [PASS in 0.10s]
# 18:00:01  58 of 87 START test unique_int_seller_performance_seller_id .................... [RUN]
# 18:00:01  57 of 87 PASS not_null_int_seller_performance_seller_id ........................ [PASS in 0.10s]
# 18:00:01  59 of 87 START sql view model marts.dim_products ............................... [RUN]
# 18:00:01  59 of 87 OK created sql view model marts.dim_products .......................... [OK in 0.03s]
# 18:00:01  60 of 87 START test accepted_values_dim_products_sales_tier__Top_Seller__Good_Seller__Low_Seller__No_Sales  [RUN]
# 18:00:01  54 of 87 PASS not_null_int_customer_orders_total_orders ........................ [PASS in 0.25s]
# 18:00:01  61 of 87 START test not_null_dim_products_category_english ..................... [RUN]
# 18:00:01  58 of 87 PASS unique_int_seller_performance_seller_id .......................... [PASS in 0.12s]
# 18:00:01  62 of 87 START test not_null_dim_products_product_key .......................... [RUN]
# 18:00:01  55 of 87 PASS not_null_int_customer_orders_total_revenue ....................... [PASS in 0.27s]
# 18:00:01  63 of 87 START test relationships_fct_order_items_product_key__product_key__ref_dim_products_  [RUN]
# 18:00:01  60 of 87 PASS accepted_values_dim_products_sales_tier__Top_Seller__Good_Seller__Low_Seller__No_Sales  [PASS in 0.11s]
# 18:00:01  64 of 87 START test unique_dim_products_product_key ............................ [RUN]
# 18:00:01  61 of 87 PASS not_null_dim_products_category_english ........................... [PASS in 0.10s]
# 18:00:01  65 of 87 START sql view model marts.dim_sellers ................................ [RUN]
# 18:00:01  62 of 87 PASS not_null_dim_products_product_key ................................ [PASS in 0.12s]
# 18:00:01  66 of 87 START sql view model intermediate.int_rfm_scores ...................... [RUN]
# 18:00:01  64 of 87 PASS unique_dim_products_product_key .................................. [PASS in 0.13s]
# 18:00:01  65 of 87 OK created sql view model marts.dim_sellers ........................... [OK in 0.08s]
# 18:00:01  63 of 87 PASS relationships_fct_order_items_product_key__product_key__ref_dim_products_  [PASS in 0.15s]
# 18:00:01  67 of 87 START test accepted_values_dim_sellers_performance_tier__Top_Seller__High_Performer__Medium_Performer__Low_Performer__No_Sales  [RUN]
# 18:00:01  68 of 87 START test not_null_dim_sellers_seller_key ............................ [RUN]
# 18:00:01  66 of 87 OK created sql view model intermediate.int_rfm_scores ................. [OK in 0.05s]
# 18:00:01  69 of 87 START test relationships_fct_order_items_seller_key__seller_key__ref_dim_sellers_  [RUN]
# 18:00:01  70 of 87 START test unique_dim_sellers_seller_key .............................. [RUN]
# 18:00:01  67 of 87 PASS accepted_values_dim_sellers_performance_tier__Top_Seller__High_Performer__Medium_Performer__Low_Performer__No_Sales  [PASS in 0.11s]
# 18:00:01  71 of 87 START test accepted_values_int_rfm_scores_customer_segment__Champions__Loyal_Customers__Potential_Loyalists__Recent_Customers__Promising__Need_Attention__At_Risk__Cannot_Lose_Them__Hibernating__Lost  [RUN]
# 18:00:01  70 of 87 PASS unique_dim_sellers_seller_key .................................... [PASS in 0.11s]
# 18:00:01  72 of 87 START test accepted_values_int_rfm_scores_frequency_score__1__2__3__4__5  [RUN]
# 18:00:01  68 of 87 PASS not_null_dim_sellers_seller_key .................................. [PASS in 0.13s]
# 18:00:01  73 of 87 START test accepted_values_int_rfm_scores_monetary_score__1__2__3__4__5  [RUN]
# 18:00:01  69 of 87 PASS relationships_fct_order_items_seller_key__seller_key__ref_dim_sellers_  [PASS in 0.14s]
# 18:00:01  74 of 87 START test accepted_values_int_rfm_scores_recency_score__1__2__3__4__5  [RUN]
# 18:00:02  71 of 87 PASS accepted_values_int_rfm_scores_customer_segment__Champions__Loyal_Customers__Potential_Loyalists__Recent_Customers__Promising__Need_Attention__At_Risk__Cannot_Lose_Them__Hibernating__Lost  [PASS in 0.35s]
# 18:00:02  75 of 87 START test not_null_int_rfm_scores_customer_segment ................... [RUN]
# 18:00:02  73 of 87 PASS accepted_values_int_rfm_scores_monetary_score__1__2__3__4__5 ..... [PASS in 0.34s]
# 18:00:02  76 of 87 START test not_null_int_rfm_scores_customer_unique_id ................. [RUN]
# 18:00:02  72 of 87 PASS accepted_values_int_rfm_scores_frequency_score__1__2__3__4__5 .... [PASS in 0.36s]
# 18:00:02  77 of 87 START test not_null_int_rfm_scores_frequency_score .................... [RUN]
# 18:00:02  74 of 87 PASS accepted_values_int_rfm_scores_recency_score__1__2__3__4__5 ...... [PASS in 0.35s]
# 18:00:02  78 of 87 START test not_null_int_rfm_scores_monetary_score ..................... [RUN]
# 18:00:02  75 of 87 PASS not_null_int_rfm_scores_customer_segment ......................... [PASS in 0.05s]
# 18:00:02  79 of 87 START test not_null_int_rfm_scores_recency_score ...................... [RUN]
# 18:00:02  76 of 87 PASS not_null_int_rfm_scores_customer_unique_id ....................... [PASS in 0.39s]
# 18:00:02  80 of 87 START test unique_int_rfm_scores_customer_unique_id ................... [RUN]
# 18:00:02  78 of 87 PASS not_null_int_rfm_scores_monetary_score ........................... [PASS in 0.38s]
# 18:00:02  77 of 87 PASS not_null_int_rfm_scores_frequency_score .......................... [PASS in 0.41s]
# 18:00:02  79 of 87 PASS not_null_int_rfm_scores_recency_score ............................ [PASS in 0.39s]
# 18:00:02  80 of 87 PASS unique_int_rfm_scores_customer_unique_id ......................... [PASS in 0.28s]
# 18:00:02  81 of 87 START sql view model marts.dim_customers .............................. [RUN]
# 18:00:02  81 of 87 OK created sql view model marts.dim_customers ......................... [OK in 0.03s]
# 18:00:02  82 of 87 START test accepted_values_dim_customers_customer_segment__Champions__Loyal_Customers__Potential_Loyalists__Recent_Customers__Promising__Need_Attention__At_Risk__Cannot_Lose_Them__Hibernating__Lost  [RUN]
# 18:00:02  83 of 87 START test accepted_values_dim_customers_customer_tier__High_Value__Medium_Value__Low_Value  [RUN]
# 18:00:02  84 of 87 START test not_null_dim_customers_customer_key ........................ [RUN]
# 18:00:02  85 of 87 START test relationships_fct_order_items_customer_key__customer_key__ref_dim_customers_  [RUN]
# 18:00:03  82 of 87 PASS accepted_values_dim_customers_customer_segment__Champions__Loyal_Customers__Potential_Loyalists__Recent_Customers__Promising__Need_Attention__At_Risk__Cannot_Lose_Them__Hibernating__Lost  [PASS in 0.62s]
# 18:00:03  86 of 87 START test relationships_fct_orders_customer_key__customer_key__ref_dim_customers_  [RUN]
# 18:00:03  83 of 87 PASS accepted_values_dim_customers_customer_tier__High_Value__Medium_Value__Low_Value  [PASS in 0.66s]
# 18:00:03  87 of 87 START test unique_dim_customers_customer_key .......................... [RUN]
# 18:00:03  85 of 87 PASS relationships_fct_order_items_customer_key__customer_key__ref_dim_customers_  [PASS in 0.78s]
# 18:00:03  84 of 87 PASS not_null_dim_customers_customer_key .............................. [PASS in 0.80s]
# 18:00:04  87 of 87 PASS unique_dim_customers_customer_key ................................ [PASS in 0.65s]
# 18:00:04  86 of 87 PASS relationships_fct_orders_customer_key__customer_key__ref_dim_customers_  [PASS in 0.78s]
# 18:00:04
# 18:00:04  Finished running 70 data tests, 17 view models in 0 hours 0 minutes and 4.80 seconds (4.80s).
# 18:00:04
# 18:00:04  Completed successfully
# 18:00:04
# 18:00:04  Done. PASS=87 WARN=0 ERROR=0 SKIP=0 TOTAL=87
#
# ================================================================================
# Return code: 0
# CompletedProcess(args=['dbt', 'build', '--profiles-dir', 'D:\\repos\\dbt-ml-analytics-pipeline\\dbt', '--project-dir', 'D:\\repos\\dbt-ml-analytics-pipeline\\dbt\\ecommerce_analytics'], returncode=0, stdout="\x1b17:59:58  Running with dbt=1.8.9\n\x1b17:59:58  Registered adapter: duckdb=1.10.0\n\x1b17:59:59  [\x1bWARNING\x1b[0m]: Configuration paths exist in your dbt_project.yml file which do not apply to any resources.\nThere are 2 unused configuration paths:\n- seeds.ecommerce_analytics\n- snapshots.ecommerce_analytics\n\x1b17:59:59  Found 17 models, 70 data tests, 9 sources, 444 macros\n\x1b17:59:59  \n\x1b17:59:59  Concurrency: 4 threads (target='dev')\n\x1b17:59:59  \n\x1b17:59:59  1 of 87 START sql view model staging.stg_geolocation ........................... [RUN]\n\x1b17:59:59  2 of 87 START sql view model staging.stg_order_payments ........................ [RUN]\n\x1b17:59:59  3 of 87 START sql view model staging.stg_order_reviews ......................... [RUN]\n\x1b17:59:59  4 of 87 START test source_accepted_values_raw_olist_orders_dataset_order_status__delivered__shipped__canceled__unavailable__invoiced__processing__created__approved  [RUN]\n\x1b17:59:59  4 of 87 PASS source_accepted_values_raw_olist_orders_dataset_order_status__delivered__shipped__canceled__unavailable__invoiced__processing__created__approved  [\x1bPASS\x1b in 0.14s]\n\x1b17:59:59  5 of 87 START test source_not_null_raw_olist_customers_dataset_customer_id ..... [RUN]\n\x1b17:59:59  1 of 87 OK created sql view model staging.stg_geolocation ...................... [\x1bOK\x1b in 0.16s]\n\x1b17:59:59  2 of 87 OK created sql view model staging.stg_order_payments ................... [\x1bOK\x1b in 0.16s]\n\x1b17:59:59  6 of 87 START test source_not_null_raw_olist_customers_dataset_customer_state .. [RUN]\n\x1b17:59:59  3 of 87 OK created sql view model staging.stg_order_reviews .................... [\x1bOK\x1b in 0.16s]\n\x1b17:59:59  7 of 87 START test source_not_null_raw_olist_customers_dataset_customer_unique_id  [RUN]\n\x1b17:59:59  8 of 87 START test source_not_null_raw_olist_customers_dataset_customer_zip_code_prefix  [RUN]\n\x1b17:59:59  5 of 87 PASS source_not_null_raw_olist_customers_dataset_customer_id ........... [\x1bPASS\x1b in 0.05s]\n\x1b17:59:59  9 of 87 START test source_not_null_raw_olist_order_items_dataset_order_id ...... [RUN]\n\x1b17:59:59  6 of 87 PASS source_not_null_raw_olist_customers_dataset_customer_state ........ [\x1bPASS\x1b in 0.06s]\n\x1b17:59:59  10 of 87 START test source_not_null_raw_olist_order_items_dataset_order_item_id  [RUN]\n\x1b17:59:59  7 of 87 PASS source_not_null_raw_olist_customers_dataset_customer_unique_id .... [\x1bPASS\x1b in 0.07s]\n\x1b17:59:59  11 of 87 START test source_not_null_raw_olist_order_items_dataset_product_id ... [RUN]\n\x1b17:59:59  8 of 87 PASS source_not_null_raw_olist_customers_dataset_customer_zip_code_prefix  [\x1bPASS\x1b in 0.07s]\n\x1b17:59:59  12 of 87 START test source_not_null_raw_olist_order_items_dataset_seller_id .... [RUN]\n\x1b17:59:59  9 of 87 PASS source_not_null_raw_olist_order_items_dataset_order_id ............ [\x1bPASS\x1b in 0.07s]\n\x1b17:59:59  13 of 87 START test source_not_null_raw_olist_orders_dataset_customer_id ....... [RUN]\n\x1b17:59:59  10 of 87 PASS source_not_null_raw_olist_order_items_dataset_order_item_id ...... [\x1bPASS\x1b in 0.07s]\n\x1b17:59:59  14 of 87 START test source_not_null_raw_olist_orders_dataset_order_id .......... [RUN]\n\x1b17:59:59  12 of 87 PASS source_not_null_raw_olist_order_items_dataset_seller_id .......... [\x1bPASS\x1b in 0.06s]\n\x1b17:59:59  15 of 87 START test source_not_null_raw_olist_orders_dataset_order_purchase_timestamp  [RUN]\n\x1b18:00:00  11 of 87 PASS source_not_null_raw_olist_order_items_dataset_product_id ......... [\x1bPASS\x1b in 0.09s]\n\x1b18:00:00  16 of 87 START test source_not_null_raw_olist_orders_dataset_order_status ...... [RUN]\n\x1b18:00:00  13 of 87 PASS source_not_null_raw_olist_orders_dataset_cust ...

# %% [markdown]
# ---
#
# ## Part 2: SQL Linting with sqlfluff
#
# Check SQL code quality and formatting using sqlfluff.

# %%
def run_sqlfluff(command, *args):
    """
    Run sqlfluff commands on dbt models.
    
    Args:
        command: sqlfluff command ('lint', 'fix')
        *args: Additional arguments (e.g., 'models/staging')
    
    Examples:
        run_sqlfluff('lint')  # Lint all models
        run_sqlfluff('lint', 'models/staging')  # Lint staging models
        run_sqlfluff('fix', 'models/marts/fct_orders.sql')  # Fix a specific file
    """
    # Build the command
    cmd = ['sqlfluff', command]
    
    if args:
        # If specific paths provided, use them
        cmd.extend(args)
    else:
        # Default to all models
        cmd.append('models')
    
    # Add common flags
    cmd.extend([
        '--dialect', 'duckdb',
        '--exclude-rules', 'L034'  # Exclude "SELECT *" warning for staging models
    ])
    
    print(f"Running: {' '.join(cmd)}")
    print(f"Working directory: {dbt_project_dir}")
    print("=" * 80)
    
    # Run the command
    result = subprocess.run(
        cmd,
        cwd=dbt_project_dir,
        capture_output=True,
        text=True
    )
    
    # Display output
    print(result.stdout)
    if result.stderr:
        print("STDERR:", result.stderr)
    
    print("=" * 80)
    print(f"Return code: {result.returncode}")
    
    return result

print("sqlfluff helper loaded successfully!")
# Out:
# sqlfluff helper loaded successfully!

# %% [markdown]
# ### Common sqlfluff Commands

# %%
# Lint all models
# run_sqlfluff('lint')

# %%
# Lint only staging models
# run_sqlfluff('lint', 'models/staging')

# %%
# Lint a specific file
# run_sqlfluff('lint', 'models/marts/fct_orders.sql')

# %%
# Lint entire dbt project (models, macros, analyses, etc.)
# run_sqlfluff('lint', '.')

# %%
# Auto-fix linting issues (use with caution!)
# run_sqlfluff('fix', 'models/staging')

# %% [markdown]
# **Note:** sqlfluff is configured to use the DuckDB dialect and excludes rule L034 (SELECT * warnings) for staging models. You can customize rules by creating a `.sqlfluff` config file in the dbt project directory.

# %% [markdown]
# ---
#
# ## Part 3: Database Inspection
#
# After running dbt, explore the database structure and query the data.

# %%
import duckdb
import pandas as pd
import sqlparse
from pathlib import Path

# Connect to database
db_path = Path('../ecommerce.duckdb')
con = duckdb.connect(str(db_path), read_only=True)

print(f"Connected to: {db_path}")
print(f"Database size: {db_path.stat().st_size / 1024 / 1024:.2f} MB")
# Out:
# Connected to: ..\ecommerce.duckdb
# Database size: 45.01 MB

# %% [markdown]
# ### 1. Database Schemas

# %%
# List all schemas
schemas_df = con.execute("""
    SELECT DISTINCT schema_name 
    FROM information_schema.schemata 
    WHERE schema_name NOT IN ('information_schema', 'pg_catalog', 'temp', 'system')
    ORDER BY schema_name
""").df()

print("Available Schemas:")
display(schemas_df)
# Out:
# Available Schemas:
#     schema_name
# 0  intermediate
# 1          main
# 2         marts
# 3           raw
# 4       staging
# 5  test_results

# %% [markdown]
# ### 2. Tables and Views by Schema

# %%
# Get all tables and views
objects_df = con.execute("""
    SELECT 
        table_schema as schema,
        table_name as name,
        table_type as type
    FROM information_schema.tables
    WHERE table_schema NOT IN ('information_schema', 'pg_catalog', 'temp', 'system')
    ORDER BY table_schema, table_type, table_name
""").df()

print(f"Total objects: {len(objects_df)}")
display(objects_df)
# Out:
# Total objects: 96
#           schema                                           name        type
# 0   intermediate                            int_customer_orders        VIEW
# 1   intermediate                        int_product_performance        VIEW
# 2   intermediate                                 int_rfm_scores        VIEW
# 3   intermediate                         int_seller_performance        VIEW
# 4          marts                                  dim_customers        VIEW
# ..           ...                                            ...         ...
# 91  test_results                    unique_fct_orders_order_key  BASE TABLE
# 92  test_results  unique_int_customer_orders_customer_unique_id  BASE TABLE
# 93  test_results      unique_int_product_performance_product_id  BASE TABLE
# 94  test_results       unique_int_rfm_scores_customer_unique_id  BASE TABLE
# 95  test_results        unique_int_seller_performance_seller_id  BASE TABLE
#
# [96 rows x 3 columns]

# %%
# Summary by schema and type
summary = objects_df.groupby(['schema', 'type']).size().reset_index(name='count')
print("\nSummary by Schema and Type:")
display(summary)
# Out:
# Summary by Schema and Type:
#          schema        type  count
# 0  intermediate        VIEW      4
# 1         marts        VIEW      5
# 2           raw  BASE TABLE      9
# 3       staging        VIEW      8
# 4  test_results  BASE TABLE     70

# %% [markdown]
# ### 3. View SQL Definitions
#
# Use this cell to view the compiled SQL for any view in the database.

# %%
def show_view_sql(schema_name, view_name):
    """
    Display the SQL definition for a specific view.
    
    Args:
        schema_name: Schema containing the view (e.g., 'staging', 'intermediate')
        view_name: Name of the view (e.g., 'stg_orders', 'int_customer_orders')
    """
    result = con.execute("""
        SELECT sql 
        FROM duckdb_views() 
        WHERE schema_name = ? AND view_name = ?
    """, [schema_name, view_name]).fetchone()
    
    if result:
        sql = result[0]
        
        # Format the SQL for better readability
        formatted_sql = sqlparse.format(
            sql,
            reindent=True,
            keyword_case='upper',
            indent_width=4
        )
        
        print(f"\n{'='*80}")
        print(f"VIEW: {schema_name}.{view_name}")
        print(f"{'='*80}\n")
        print(formatted_sql)
        print(f"\n{'='*80}\n")
    else:
        print(f"View '{schema_name}.{view_name}' not found.")
        print("\nAvailable views:")
        views = con.execute("""
            SELECT schema_name, view_name 
            FROM duckdb_views() 
            ORDER BY schema_name, view_name
        """).df()
        display(views)

# Example usage:
show_view_sql('staging', 'stg_orders')
# Out:
# ================================================================================
# VIEW: staging.stg_orders
# ================================================================================
#
# CREATE VIEW staging.stg_orders AS WITH SOURCE AS
#     (SELECT *
#      FROM ecommerce.raw.olist_orders_dataset), cleaned AS
#     (SELECT order_id,
#             customer_id,
#             order_status,
#             order_purchase_timestamp AS purchased_at,
#             order_approved_at AS approved_at,
#             order_delivered_carrier_date AS carrier_delivered_at,
#             order_delivered_customer_date AS customer_delivered_at,
#             order_estimated_delivery_date AS estimated_delivery_date,
#             CASE
#                 WHEN (((order_delivered_customer_date IS NOT NULL)
#                        AND (order_estimated_delivery_date IS NOT NULL))) THEN (datediff('day', order_estimated_delivery_date, CAST(order_delivered_customer_date AS DATE)))
#                 ELSE NULL
#             END AS delivery_delay_days,
#             COALESCE(((order_delivered_customer_date IS NOT NULL)
#                       AND (CAST(order_delivered_customer_date AS DATE) > order_estimated_delivery_date)), CAST('f' AS BOOLEAN)) AS is_late_delivery
#      FROM SOURCE)
# SELECT *
# FROM cleaned;
#
# ================================================================================

# %%
# Show another view - change these values as needed
show_view_sql('intermediate', 'int_customer_orders')
# Out:
# ================================================================================
# VIEW: intermediate.int_customer_orders
# ================================================================================
#
# CREATE VIEW intermediate.int_customer_orders AS WITH orders AS
#     (SELECT *
#      FROM ecommerce.staging.stg_orders),
#                                                      order_items AS
#     (SELECT *
#      FROM ecommerce.staging.stg_order_items),
#                                                      payments AS
#     (SELECT *
#      FROM ecommerce.staging.stg_order_payments),
#                                                      reviews AS
#     (SELECT *
#      FROM ecommerce.staging.stg_order_reviews),
#                                                      customers AS
#     (SELECT *
#      FROM ecommerce.staging.stg_customers),
#                                                      order_totals AS
#     (SELECT order_id,
#             sum(total_price) AS order_value,
#             sum(item_price) AS items_value,
#             sum(freight_price) AS freight_value,
#             count_star() AS items_count
#      FROM order_items
#      GROUP BY order_id),
#                                                      payment_totals AS
#     (SELECT order_id,
#             sum(payment_value) AS total_paid,
#             count_star() AS payment_count,
#             max(payment_installments) AS max_installments
#      FROM payments
#      GROUP BY order_id),
#                                                      review_scores AS
#     (SELECT order_id,
#             review_score,
#             sentiment,
#             has_comment
#      FROM reviews),
#                                                      order_enriched AS
#     (SELECT o.order_id,
#             o.customer_id,
#             c.customer_unique_id,
#             c.state AS customer_state,
#             o.order_status,
#             o.purchased_at,
#             o.customer_delivered_at,
#             o.estimated_delivery_date,
#             o.delivery_delay_days,
#             o.is_late_delivery,
#             r.review_score,
#             r.sentiment,
#             r.has_comment,
#             COALESCE(ot.order_value, 0) AS order_value,
#             COALESCE(ot.items_value, 0) AS items_value,
#             COALESCE(ot.freight_value, 0) AS freight_value,
#             COALESCE(ot.items_count, 0) AS items_count,
#             COALESCE(pt.total_paid, 0) AS total_paid,
#             COALESCE(pt.payment_count, 0) AS payment_count,
#             COALESCE(pt.max_installments, 1) AS max_installments
#      FROM orders AS o
#      LEFT JOIN customers AS c ON ((o.customer_id = c.customer_id))
#      LEFT JOIN order_totals AS ot ON ((o.order_id = ot.order_id))
#      LEFT JOIN payment_totals AS pt ON ((o.order_id = pt.order_id))
#      LEFT JOIN review_scores AS r ON ((o.order_id = r.order_id))),
#                                                      customer_aggregates AS
#     (SELECT customer_unique_id,
#             count(DISTINCT order_id) AS total_orders,
#             count(DISTINCT CASE
#                                WHEN ((order_status = 'delivered')) THEN (order_id)
#                                ELSE NULL
#                            END) AS delivered_orders,
#             count(DISTINCT CASE
#                                WHEN ((order_status = 'canceled')) THEN (order_id)
#                                ELSE NULL
#                            END) AS canceled_orders,
#             sum(CASE
#                     WHEN ((order_status = 'delivered')) THEN (order_value)
#                     ELSE 0
#                 END) AS total_revenue,
#             avg(CASE
#                     WHEN ((order_status = 'delivered')) THEN (order_value)
#                     ELSE NULL
#                 END) AS avg_order_value,
#             max(CASE
#                     WHEN ((order_status = 'delivered')) THEN (order_value)
#                     ELSE NULL
#                 END) AS max_order_value,
#             sum(CASE
#                     WHEN ((order_status = 'delivered')) THEN (freight_value)
#                     ELSE 0
#                 END) AS total_freight_paid,
#             avg(CASE
#                     WHEN ((order_status = 'delivered')) THEN (delivery_delay_days)
#                     ELSE NULL
#                 END) AS avg_delivery_delay_days,
#             count(CASE
#                       WHEN ((is_late_delivery = CAST('t' AS BOOLEAN))) THEN (1)
#                       ELSE NULL
#                   END) AS late_deliveries,
#             avg(review_score) AS avg_review_score,
#             count(CASE
#                       WHEN ((review_score <= 2)) THEN (1)
#                       ELSE NULL
#                   END) AS negative_reviews,
#             count(CASE
#                       WHEN ((review_score >= 4)) THEN (1)
#                       ELSE NULL
#                   END) AS positive_reviews,
#             datediff('day', CAST(max(purchased_at) AS DATE), CAST('2018-08-31' AS DATE)) AS days_since_last_order,
#             min(purchased_at) AS first_order_date,
#             max(purchased_at) AS last_order_date,
#             max(customer_state) AS customer_state
#      FROM order_enriched
#      GROUP BY customer_unique_id)
# SELECT *
# FROM customer_aggregates;
#
# ================================================================================

# %% [markdown]
# ### 4. List All Available Views

# %%
# Get all views with their schemas
views_df = con.execute("""
    SELECT 
        schema_name,
        view_name,
        length(sql) as sql_length
    FROM duckdb_views()
    WHERE schema_name NOT IN ('information_schema', 'pg_catalog')
    ORDER BY schema_name, view_name
""").df()

print(f"Total views: {len(views_df)}")
display(views_df)
# Out:
# Total views: 56
#      schema_name                view_name  sql_length
# 0   intermediate      int_customer_orders        3131
# 1   intermediate  int_product_performance        2754
# 2   intermediate           int_rfm_scores        1853
# 3   intermediate   int_seller_performance        3159
# 4           main           duckdb_columns          92
# 5           main           duckdb_columns          92
# 6           main           duckdb_columns          92
# 7           main       duckdb_constraints          79
# 8           main       duckdb_constraints          79
# 9           main       duckdb_constraints          79
# 10          main         duckdb_databases          96
# 11          main         duckdb_databases          96
# 12          main         duckdb_databases          96
# 13          main           duckdb_indexes          71
# 14          main           duckdb_indexes          71
# 15          main           duckdb_indexes          71
# 16          main           duckdb_schemas          92
# 17          main           duckdb_schemas          92
# 18          main           duckdb_schemas          92
# 19          main            duckdb_tables          90
# 20          main            duckdb_tables          90
# 21          main            duckdb_tables          90
# 22          main             duckdb_types          67
# 23          main             duckdb_types          67
# 24          main             duckdb_types          67
# 25          main             duckdb_views          88
# 26          main             duckdb_views          88
# 27          main             duckdb_views          88
# 28          main     pragma_database_list         168
# 29          main     pragma_database_list         168
# 30          main     pragma_database_list         168
# 31          main            sqlite_master         400
# 32          main            sqlite_master         400
# 33          main            sqlite_master         400
# 34          main            sqlite_schema          67
# 35          main            sqlite_schema          67
# 36          main            sqlite_schema          67
# 37          main       sqlite_temp_master          72
# 38          main       sqlite_temp_master          72
# 39          main       sqlite_temp_master          72
# 40          main       sqlite_temp_schema          72
# 41          main       sqlite_temp_schema          72
# 42          main       sqlite_temp_schema          72
# 43         marts            dim_customers        1479
# 44         marts             dim_products         506
# 45         marts              dim_sellers         498
# 46         marts          fct_order_items         939
# 47         marts               fct_orders        2755
# 48       staging            stg_customers         285
# 49       staging          stg_geolocation         395
# 50       staging          stg_order_items         325
# 51       staging       stg_order_payments         512
# 52       staging        stg_order_reviews         593
# 53       staging               stg_orders         859
# 54       staging             stg_products         903
# 55       staging              stg_sellers         253

# %% [markdown]
# ### 5. Table Row Counts

# %%
# Get row counts for all tables
def get_row_counts():
    tables = con.execute("""
        SELECT table_schema, table_name 
        FROM information_schema.tables
        WHERE table_type = 'BASE TABLE'
        AND table_schema NOT IN ('information_schema', 'pg_catalog', 'temp', 'system')
        ORDER BY table_schema, table_name
    """).fetchall()
    
    results = []
    for schema, table in tables:
        count = con.execute(f'SELECT COUNT(*) FROM "{schema}"."{table}"').fetchone()[0]
        results.append({'schema': schema, 'table': table, 'row_count': count})
    
    return pd.DataFrame(results)

row_counts_df = get_row_counts()
display(row_counts_df)
# Out:
#           schema                                          table  row_count
# 0            raw                        olist_customers_dataset      99441
# 1            raw                      olist_geolocation_dataset    1000163
# 2            raw                      olist_order_items_dataset     112650
# 3            raw                   olist_order_payments_dataset     103886
# 4            raw                    olist_order_reviews_dataset      99224
# ..           ...                                            ...        ...
# 74  test_results                    unique_fct_orders_order_key          0
# 75  test_results  unique_int_customer_orders_customer_unique_id          0
# 76  test_results      unique_int_product_performance_product_id          0
# 77  test_results       unique_int_rfm_scores_customer_unique_id          0
# 78  test_results        unique_int_seller_performance_seller_id          0
#
# [79 rows x 3 columns]

# %% [markdown]
# ### 6. Table Schema Details

# %%
def describe_table(schema_name, table_name):
    """
    Show detailed schema for a specific table or view.
    
    Args:
        schema_name: Schema name (e.g., 'marts', 'staging')
        table_name: Table/view name (e.g., 'fct_orders', 'stg_customers')
    """
    print(f"\nSchema for {schema_name}.{table_name}:")
    print("="*80)
    
    result = con.execute(f'DESCRIBE "{schema_name}"."{table_name}"').df()
    display(result)
    
    # Show sample rows
    print(f"\nSample data (first 5 rows):")
    sample = con.execute(f'SELECT * FROM "{schema_name}"."{table_name}" LIMIT 5').df()
    display(sample)

# Example usage:
describe_table('marts', 'fct_orders')
# Out:
# Schema for marts.fct_orders:
# ================================================================================
#                 column_name               column_type null   key default extra
# 0                 order_key                   VARCHAR  YES  None    None  None
# 1              customer_key                   VARCHAR  YES  None    None  None
# 2            order_date_key                      DATE  YES  None    None  None
# 3              order_status                   VARCHAR  YES  None    None  None
# 4              purchased_at                 TIMESTAMP  YES  None    None  None
# 5               approved_at                 TIMESTAMP  YES  None    None  None
# 6      carrier_delivered_at                 TIMESTAMP  YES  None    None  None
# 7     customer_delivered_at                 TIMESTAMP  YES  None    None  None
# 8   estimated_delivery_date                 TIMESTAMP  YES  None    None  None
# 9       delivery_delay_days                    BIGINT  YES  None    None  None
# 10         is_late_delivery                   BOOLEAN  YES  None    None  None
# 11     primary_payment_type                   VARCHAR  YES  None    None  None
# 12             review_score                    BIGINT  YES  None    None  None
# 13                sentiment                   VARCHAR  YES  None    None  None
# 14              has_comment                   BOOLEAN  YES  None    None  None
# 15           customer_state                   VARCHAR  YES  None    None  None
# 16            customer_city                   VARCHAR  YES  None    None  None
# 17          days_to_carrier                    BIGINT  YES  None    None  None
# 18          days_in_transit                    BIGINT  YES  None    None  None
# 19         days_to_customer                    BIGINT  YES  None    None  None
# 20              order_value                    DOUBLE  YES  None    None  None
# 21              items_value                    DOUBLE  YES  None    None  None
# 22            freight_value                    DOUBLE  YES  None    None  None
# 23               total_paid                    DOUBLE  YES  None    None  None
# 24            payment_count                    BIGINT  YES  None    None  None
# 25         max_installments                    BIGINT  YES  None    None  None
# 26              items_count                    BIGINT  YES  None    None  None
# 27          unique_products                    BIGINT  YES  None    None  None
# 28           unique_sellers                    BIGINT  YES  None    None  None
# 29             is_delivered                   BOOLEAN  YES  None    None  None
# 30              is_canceled                   BOOLEAN  YES  None    None  None
# 31          is_multi_seller                   BOOLEAN  YES  None    None  None
# 32               created_at  TIMESTAMP WITH TIME ZONE  YES  None    None  None
# Sample data (first 5 rows):
#                           order_key                      customer_key  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 1  53cdb2fc8bc7dce0b6741e2150273451  af07308b275d755c9edb36a90c618231
# 2  47770eb9100c2d0c44946d9cf07ec65d  3a653a41f6f9fc3d2a113cf8398680e8
# 3  949d5b44dbf5de918fe9c16f97b45f8a  7c142cf63193a1473d2e66489a9ae977
# 4  ad21c59c0840e6cb83a9ceb5573f8159  72632f0f9dd73dfee390c9b22eb56dd6
#
#   order_date_key order_status        purchased_at         approved_at  \
# 0     2017-10-02    delivered 2017-10-02 10:56:33 2017-10-02 11:07:15
# 1     2018-07-24    delivered 2018-07-24 20:41:37 2018-07-26 03:24:27
# 2     2018-08-08    delivered 2018-08-08 08:38:49 2018-08-08 08:55:23
# 3     2017-11-18    delivered 2017-11-18 19:28:06 2017-11-18 19:45:59
# 4     2018-02-13    delivered 2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   carrier_delivered_at customer_delivered_at estimated_delivery_date  \
# 0  2017-10-04 19:55:00   2017-10-10 21:25:13              2017-10-18
# 1  2018-07-26 14:31:00   2018-08-07 15:27:45              2018-08-13
# 2  2018-08-08 13:50:00   2018-08-17 18:06:29              2018-09-04
# 3  2017-11-22 13:39:59   2017-12-02 00:28:42              2017-12-15
# 4  2018-02-14 19:46:34   2018-02-16 18:17:02              2018-02-26
#
#    delivery_delay_days  ...  total_paid payment_count  max_installments  \
# 0                   -8  ...       38.71             3                 1
# 1                   -6  ...      141.46             1                 1
# 2                  -18  ...      179.12             1                 3
# 3                  -13  ...       72.20             1                 1
# 4                  -10  ...       28.62             1                 1
#
#   items_count  unique_products unique_sellers is_delivered  is_canceled  \
# 0           1                1              1         True        False
# 1           1                1              1         True        False
# 2           1                1              1         True        False
# 3           1                1              1         True        False
# 4           1                1              1         True        False
#
#    is_multi_seller                       created_at
# 0            False 2026-01-03 12:00:05.308000-06:00
# 1            False 2026-01-03 12:00:05.308000-06:00
# 2            False 2026-01-03 12:00:05.308000-06:00
# 3            False 2026-01-03 12:00:05.308000-06:00
# 4            False 2026-01-03 12:00:05.308000-06:00
#
# [5 rows x 33 columns]

# %% [markdown]
# ### 7. Quick Data Exploration

# %%
# Example: Order status distribution
query = """
    SELECT 
        order_status,
        COUNT(*) as order_count,
        ROUND(AVG(order_value), 2) as avg_value,
        ROUND(SUM(order_value), 2) as total_value
    FROM marts.fct_orders
    GROUP BY order_status
    ORDER BY order_count DESC
"""

result = con.execute(query).df()
print("Order Status Distribution:")
display(result)
# Out:
# Order Status Distribution:
#   order_status  order_count  avg_value  total_value
# 0    delivered        96478     159.83  15419773.75
# 1      shipped         1107     160.01    177129.34
# 2     canceled          625     169.42    105885.72
# 3  unavailable          609       3.51      2140.49
# 4     invoiced          314     219.71     68988.75
# 5   processing          301     230.55     69394.11
# 6      created            5       0.00         0.00
# 7     approved            2     120.54       241.08

# %%
# Example: Customer state distribution
query = """
    SELECT 
        state,
        COUNT(*) as customer_count
    FROM marts.dim_customers
    GROUP BY state
    ORDER BY customer_count DESC
    LIMIT 10
"""

result = con.execute(query).df()
print("Top 10 Customer States:")
display(result)
# Out:
# Top 10 Customer States:
#   state  customer_count
# 0    SP           40294
# 1    RJ           12383
# 2    MG           11255
# 3    RS            5275
# 4    PR            4880
# 5    SC            3529
# 6    BA            3276
# 7    DF            2073
# 8    ES            1964
# 9    GO            1950

# %% [markdown]
# ### 8. Close Connection

# %%
# Close the connection when done
con.close()
print("Database connection closed.")
# Out:
# Database connection closed.
